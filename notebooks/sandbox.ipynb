# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from loguru import logger
import tensorflow as tf

from keras.models import Sequential
from keras.layers import Dense, BatchNormalization, Dropout, Normalization
from keras.optimizers import Adam, SGD, RMSprop, Adadelta, Adagrad, Adamax, Nadam, Ftrl
from keras.callbacks import EarlyStopping, ModelCheckpoint
from scikeras.wrappers import KerasRegressor
from keras.optimizers.schedules import ExponentialDecay

from math import floor
from sklearn.metrics import make_scorer, mean_squared_error
from bayes_opt import BayesianOptimization
from sklearn.model_selection import KFold
import pickle
from keras.layers import LeakyReLU

import warnings
warnings.filterwarnings('ignore')
pd.set_option("display.max_columns", None)

# %%
from parcsann.utils.dir import get_project_root
import os
from dotenv import load_dotenv

root_dir = get_project_root()
load_dotenv(dotenv_path=os.path.join(root_dir, ".env"))

ENV = os.getenv("ENV", "DEV")
ENV

# %%
import numpy as np
import pandas as pd

np.random.seed(42)

y_test = np.random.normal(loc=50, scale=10, size=100)
y_pred_nn = y_test + np.random.normal(loc=0, scale=3, size=100)
y_pred_lr = y_test + np.random.normal(loc=0, scale=5, size=100)

df = pd.DataFrame({
    "y_test": y_test,
    "y_pred_nn": y_pred_nn,
    "y_pred_lr": y_pred_lr
})

df

# %%
import numpy as np
import matplotlib.pyplot as plt


df["rad_nn"] = np.abs(df["y_test"] - df["y_pred_nn"]) / (np.abs(df["y_test"]))
df["rad_lr"] = np.abs(df["y_test"] - df["y_pred_lr"]) / (np.abs(df["y_test"]))

global_min = min(df["rad_nn"].min(), df["rad_lr"].min())
global_max = max(df["rad_nn"].max(), df["rad_lr"].max())
bins = np.linspace(global_min, global_max, 21)

plt.figure(figsize=(10, 6))
plt.plot(
    df["y_test"], 
    df["y_pred_nn"], 
    linestyle='None',
    marker='o', 
    markerfacecolor='none',
    markeredgecolor='blue',
    label="Neural Network"
)

plt.plot(
    df["y_test"], 
    df["y_pred_lr"], 
    linestyle='None',
    marker='s', 
    markerfacecolor='none',
    markeredgecolor='red',
    label="Linear Model"
)

min_val = df["y_test"].min()
max_val = df["y_test"].max()
plt.plot([min_val, max_val], [min_val, max_val], color='green', linestyle='--', label='y=x')

plt.legend()
plt.show()

# %%
from pathlib import Path
import os

project_dir = Path(os.getcwd()).parent
data_dir = project_dir / "data"

# %%
from parcsann.read_data.nuclear_code_data import CoreData

core_data = CoreData().process_data()

# %%
X_train, X_val, y_train, y_val = core_data.train_test_div()
# X_train = X_train[:60]
# y_train = y_train[:60]

# %%
def nn_cl_bo(neurons, activation, optimizer, learning_rate, layers1, layers2, dropout, dropout_rate, decay_steps, decay_rate):
    optimizerD = {
        'Adam': Adam,
        'RMSprop': RMSprop, 
        'Adadelta': Adadelta,
        'Adagrad': Adagrad, 
        'Adamax': Adamax,
        'Nadam': Nadam, 
        'Ftrl': Ftrl,
        'SGD': SGD,
    }
        
    activationL = ['relu', 'softplus', 'tanh', 'sigmoid', 'elu', 'linear']
    
    neurons = round(neurons)
    activation = activationL[round(activation)]
    epochs = round(epochs)
    layers1 = round(layers1)
    layers2 = round(layers2)
    decay_steps = round(decay_steps)

    def nn_cl_fun():

        lr_schedule = ExponentialDecay(
            initial_learning_rate=learning_rate,
            decay_steps=decay_steps,
            decay_rate=decay_rate,
            staircase=False
        )
        optimizer_instance = optimizerD[list(optimizerD.keys())[round(optimizer)]](
            learning_rate=lr_schedule
        )

        nn = Sequential()
        nn.add(Dense(neurons, input_dim=X_train.shape[1], activation=activation))
        for _ in range(layers1):
            nn.add(Dense(neurons, activation=activation))
        if dropout > 0.5:
            nn.add(Dropout(dropout_rate, seed=123))
        for _ in range(layers2):
            nn.add(Dense(neurons, activation=activation))
        nn.add(Dense(y_train.shape[1], activation='linear'))
        nn.compile(loss='mse', optimizer=optimizer_instance)
        return nn
    
    es = EarlyStopping(monitor='val_loss', mode='min', verbose=0, patience=20, restore_best_weights=True)
    nn = KerasRegressor(build_fn=nn_cl_fun, epochs=300, verbose=0, fit__callbacks=[es])

    kfold = KFold(n_splits=5, shuffle=True)
    
    score = cross_val_score(
        nn, X_train, y_train,
        scoring='neg_mean_squared_error',
        cv=kfold
    )

    if np.isnan(score).any():
        return -1e10

    return score.mean()

# %%
temp = {"a": 1, "b": 2}

temp2 = dict(enumerate(temp))
temp2

# %%
params_nn ={
    'neurons': (10, 120),
    'activation': (0, 5),
    'optimizer': (0, 6),
    'learning_rate': (0.00001, 0.1),
    'layers1': (1, 3),
    'layers2': (1, 3),
    'dropout': (0, 1),
    'dropout_rate': (0, 0.3),
    'decay_steps': (10, 3000),
    'decay_rate': (0.9, 0.999),
}

# Run Bayesian Optimization
nn_bo = BayesianOptimization(nn_cl_bo, params_nn)
nn_bo.maximize(init_points=25, n_iter=40)

# %%
params_nn_ = nn_bo.max['params']

activationL = ['relu', 'softplus', 'tanh', 'sigmoid', 'elu', 'linear']
params_nn_['activation'] = activationL[round(params_nn_['activation'])]

params_nn_

# %%
lr_schedule = ExponentialDecay(
    initial_learning_rate=0.008407184461804686,
    decay_steps=670,
    decay_rate=0.20753862495398942,
    staircase=False
)
optimizer_instance = Ftrl(learning_rate=lr_schedule)

nn = Sequential()
nn.add(Dense(70, input_dim=X_train.shape[1], activation='elu'))
nn.add(BatchNormalization())
for _ in range(2):
    nn.add(Dense(70, activation='elu'))
nn.add(Dropout(0.20753862495398942, seed=123))
for _ in range(3):
    nn.add(Dense(70, activation='elu'))
nn.add(Dense(70, activation='elu'))
nn.add(Dense(y_train.shape[1], activation='linear'))
nn.compile(loss='mse', optimizer=optimizer_instance)

history = nn.fit(
    X_train,
    y_train,
    epochs=100,
    validation_data=(X_val, y_val),
    verbose=1
)

# %%
y_pred = nn.predict(X_val)

# %%
plt.hist(y_pred)

# %%
nn.summary()
